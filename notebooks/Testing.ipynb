# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u

import sys
sys.path.append('..')
from src.utils import input_unit
from src.imf import PowerLawIMF, Star, EmbeddedCluster
# Out:
# C:\Users\lucas\Documents\GitHub\environIMF\notebooks\..\src\imf.py:796: SyntaxWarning: invalid escape sequence '\i'
#   """Compute the galactic initial mass function.

# %%
@input_unit((u.m, u.erg))
def f(x, y, model='a'):
    print(x, y, model)
    if model == 'a':
        return x * y
    else:
        return x /y

# %%
f
# Out:
# <function __main__.f(x, y, model='a')>

# %%
f(1, 'a', 4*u.s)
# Out:
# 1.0 m a erg 4.0 s
# <Quantity 1. m / (a erg)>

# %%
imf = PowerLawIMF(1.e6, 0.08, 150)

# %%
imf.breaks
# Out:
# array([0.0e+00, 8.0e-02, 1.0e+00, 1.5e+02])

# %%
imf.exponents
# Out:
# array([-1.3, -1.3, -2.3, -2.3])

# %%
imf.norms
# Out:
# array([1.00000000e+00, 2.64782174e+05, 2.64782174e+05, 2.64782174e+05])

# %%
imf.integrate(1, 100, normalized=False)
# Out:
# 0.7672985488988389

# %%
imf.integrate(1.1, 100, normalized=False)
# Out:
# 0.6776564922658656

# %%
x0s = np.logspace(-1, 2, 100)
imfs = [imf.integrate(x0, 149, normalized=False) for x0 in x0s]

plt.plot(x0s, imfs, '.')
plt.xscale('log')
plt.yscale('log')

# %%
imf.exponents
# Out:
# array([-1.3, -1.3, -2.3, -2.3])

# %%
imf.norms
# Out:
# array([1.00000000e+00, 2.64782174e+05, 2.64782174e+05, 2.64782174e+05])

# %%
x0s = np.logspace(-1, 2, 100)
imfs = [imf.imf(x0) for x0 in x0s]

plt.plot(x0s, imfs)
plt.xscale('log')
plt.yscale('log')

# %%
imf.norms
# Out:
# array([1.00000000e+00, 2.64782174e+05, 2.64782174e+05, 2.64782174e+05])

# %%
1.**-1.3
# Out:
# 1.0

# %%
imf.imf(0.99)
# Out:
# 268264.3670701309

# %%
imf.imf(1.01)
# Out:
# 258791.24711466793

# %%
imf.imf(1.0722)
# Out:
# 225556.0063808393

# %%
x0s = np.linspace(0.1, 100, 1000)
imf_ints = [imf.integrate(x0, 150, normalized=True) for x0 in x0s]

x0s2 = np.logspace(-1, 2, 100)
imf_ints2 = [imf.integrate(x0, 150, normalized=True) for x0 in x0s2]

plt.plot(x0s, imf_ints)

plt.plot(x0s2, imf_ints2)
plt.xscale('log')
plt.yscale('log')

# %%
x0s = np.logspace(-1, 2, 100)
imf_ints = [imf.integrate(x0, 150, normalized=True) for x0 in x0s]

plt.plot(x0s, imf_ints)
plt.xscale('log')
plt.yscale('log')

# %%
imf.m_tot
# Out:
# 1000000.0

# %%
imf.integrate(0.08, 150, mass=True)
# Out:
# 1000000.0

# %%
imf.integrate(0.08, 150, mass=False)
# Out:
# 1203726.7256386587

# %%
star = Star()

# %% [raw]
# star.m_tot

# %%
star.get_mmax_k()
