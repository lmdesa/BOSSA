# %% [markdown]
# This notebook produces figure 12 of de Sá, Bernardo et al. (2024).

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import seaborn as sns
import pandas as pd
from pathlib import Path
from scipy.interpolate import UnivariateSpline
from scipy.stats import mode

import gc 
import sys
sys.path.append('../src')
from bossa.utils import sample_histogram
from bossa.sampling import RandomSampling
from bossa.imf import IGIMF, Star
from bossa.constants import DATA_PATH, COMPACT_OBJ_DIR_PATH

# %%
plt.style.use('./plotstyle.mplstyle')
FIGURE_FOLDER = Path('./figures')

# %%
cm_cubehelix = sns.cubehelix_palette(as_cmap=True)

# %%
IGIMF_ZAMS_DIR_PATH = Path(DATA_PATH, 'zams_grids')
ONLYBIN_SAMPLE_DIR_PATH = Path(IGIMF_ZAMS_DIR_PATH, '12x10_2222_zams_grid')
ALLMULT_SAMPLE_DIR_PATH = Path(IGIMF_ZAMS_DIR_PATH, '12x10_2212_zams_grid')
ONLYBIN_CANON_SAMPLE_DIR_PATH = Path(IGIMF_ZAMS_DIR_PATH, '12x10_1122_zams_grid')
ALLMULT_CANON_SAMPLE_DIR_PATH = Path(IGIMF_ZAMS_DIR_PATH, '12x10_1112_zams_grid')

# %%
onlybin_sample_paths = list(ONLYBIN_SAMPLE_DIR_PATH.glob('*.parquet'))
allmult_sample_paths = list(ALLMULT_SAMPLE_DIR_PATH.glob('*.parquet'))
onlybin_canon_sample_paths = list(ONLYBIN_CANON_SAMPLE_DIR_PATH.glob('*.parquet'))
allmult_canon_sample_paths = list(ALLMULT_CANON_SAMPLE_DIR_PATH.glob('*.parquet'))
#sample_paths = list(CO_DIR_PATH.glob('*.parquet'))

# %%
onlybin_sample_paths
# Out:
# [PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-0.528_logsfr=1.408_1e4ZOH=85658_1e2Mgal=1058_1e2logn=-361_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=0.058_logsfr=1.476_1e4ZOH=88590_1e2Mgal=1084_1e2logn=-337_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.094_logsfr=0.613_1e4ZOH=88770_1e2Mgal=1007_1e2logn=-244_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=-0.649_logsfr=0.666_1e4ZOH=85055_1e2Mgal=955_1e2logn=-247_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.376_logsfr=1.042_1e4ZOH=90180_1e2Mgal=1090_1e2logn=-321_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.190_logsfr=-0.028_1e4ZOH=89248_1e2Mgal=983_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=0.016_logsfr=1.247_1e4ZOH=88377_1e2Mgal=1053_1e2logn=-295_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=0.264_logsfr=1.201_1e4ZOH=89619_1e2Mgal=1078_1e2logn=-308_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=0.203_logsfr=1.733_1e4ZOH=89314_1e2Mgal=1125_1e2logn=-410_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=0.314_logsfr=1.294_1e4ZOH=89868_1e2Mgal=1094_1e2logn=-331_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-3.474_logsfr=0.447_1e4ZOH=58561_1e2Mgal=863_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.174_logsfr=0.403_1e4ZOH=89170_1e2Mgal=1004_1e2logn=-237_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.342_logsfr=0.646_1e4ZOH=90009_1e2Mgal=1056_1e2logn=-274_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=-0.280_logsfr=0.259_1e4ZOH=86900_1e2Mgal=944_1e2logn=-217_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=0.208_logsfr=1.528_1e4ZOH=89341_1e2Mgal=1099_1e2logn=-348_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=0.152_logsfr=1.033_1e4ZOH=89061_1e2Mgal=1048_1e2logn=-278_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.064_logsfr=1.901_1e4ZOH=82658_1e2Mgal=1114_1e2logn=-513_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.299_logsfr=1.097_1e4ZOH=89796_1e2Mgal=1076_1e2logn=-303_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.411_logsfr=1.188_1e4ZOH=86243_1e2Mgal=1030_1e2logn=-310_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-2.548_logsfr=-0.993_1e4ZOH=67822_1e2Mgal=683_1e2logn=-143_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=-0.093_logsfr=0.945_1e4ZOH=87833_1e2Mgal=1016_1e2logn=-264_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.301_logsfr=0.573_1e4ZOH=89802_1e2Mgal=1041_1e2logn=-260_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.489_logsfr=1.015_1e4ZOH=78406_1e2Mgal=979_1e2logn=-338_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-3.094_logsfr=0.920_1e4ZOH=62357_1e2Mgal=934_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-2.760_logsfr=-0.980_1e4ZOH=65702_1e2Mgal=679_1e2logn=-146_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.423_logsfr=1.165_1e4ZOH=90412_1e2Mgal=1114_1e2logn=-371_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.358_logsfr=0.189_1e4ZOH=90091_1e2Mgal=1044_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-3.166_logsfr=-0.910_1e4ZOH=61637_1e2Mgal=677_1e2logn=-194_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=-0.184_logsfr=1.039_1e4ZOH=87378_1e2Mgal=1018_1e2logn=-273_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=-0.522_logsfr=0.588_1e4ZOH=85687_1e2Mgal=955_1e2logn=-239_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-0.852_logsfr=0.659_1e4ZOH=84041_1e2Mgal=950_1e2logn=-254_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-2.621_logsfr=1.700_1e4ZOH=67087_1e2Mgal=1047_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.407_logsfr=0.296_1e4ZOH=90333_1e2Mgal=1075_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-2.995_logsfr=1.056_1e4ZOH=63345_1e2Mgal=954_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=0.266_logsfr=1.417_1e4ZOH=89632_1e2Mgal=1097_1e2logn=-339_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.273_logsfr=0.061_1e4ZOH=89663_1e2Mgal=1008_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=0.212_logsfr=1.117_1e4ZOH=89359_1e2Mgal=1063_1e2logn=-291_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.196_logsfr=0.933_1e4ZOH=89277_1e2Mgal=1046_1e2logn=-273_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=-0.350_logsfr=0.897_1e4ZOH=86548_1e2Mgal=993_1e2logn=-261_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=0.279_logsfr=1.672_1e4ZOH=89694_1e2Mgal=1122_1e2logn=-397_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.408_logsfr=0.796_1e4ZOH=90341_1e2Mgal=1089_1e2logn=-314_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.398_logsfr=1.152_1e4ZOH=79318_1e2Mgal=1000_1e2logn=-361_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-4.578_logsfr=-0.775_1e4ZOH=47515_1e2Mgal=674_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.251_logsfr=1.015_1e4ZOH=89555_1e2Mgal=1061_1e2logn=-286_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=-2.044_logsfr=-1.162_1e4ZOH=72862_1e2Mgal=687_1e2logn=-128_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.127_logsfr=0.843_1e4ZOH=88934_1e2Mgal=1030_1e2logn=-262_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-0.671_logsfr=1.268_1e4ZOH=84945_1e2Mgal=1036_1e2logn=-342_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.377_logsfr=0.717_1e4ZOH=90182_1e2Mgal=1072_1e2logn=-290_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=-0.018_logsfr=0.836_1e4ZOH=88210_1e2Mgal=1013_1e2logn=-257_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=-0.168_logsfr=0.055_1e4ZOH=87460_1e2Mgal=939_1e2logn=-208_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=0.011_logsfr=1.052_1e4ZOH=88354_1e2Mgal=1035_1e2logn=-275_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.242_logsfr=0.798_1e4ZOH=89511_1e2Mgal=1043_1e2logn=-267_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.426_logsfr=0.354_1e4ZOH=90429_1e2Mgal=1091_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-1.209_logsfr=0.724_1e4ZOH=81210_1e2Mgal=948_1e2logn=-278_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.822_logsfr=0.868_1e4ZOH=84190_1e2Mgal=978_1e2logn=-279_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=-0.035_logsfr=0.485_1e4ZOH=88122_1e2Mgal=982_1e2logn=-232_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.059_logsfr=0.285_1e4ZOH=88594_1e2Mgal=978_1e2logn=-224_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.323_logsfr=0.130_1e4ZOH=89916_1e2Mgal=1027_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.035_logsfr=0.740_1e4ZOH=88475_1e2Mgal=1010_1e2logn=-251_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=0.212_logsfr=1.320_1e4ZOH=89359_1e2Mgal=1080_1e2logn=-315_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=-1.974_logsfr=-1.231_1e4ZOH=73561_1e2Mgal=687_1e2logn=-123_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.447_logsfr=0.437_1e4ZOH=90535_1e2Mgal=1115_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=-2.245_logsfr=-1.019_1e4ZOH=70845_1e2Mgal=686_1e2logn=-139_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.293_logsfr=0.878_1e4ZOH=89762_1e2Mgal=1058_1e2logn=-280_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-1.128_logsfr=0.577_1e4ZOH=82020_1e2Mgal=932_1e2logn=-257_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.187_logsfr=1.414_1e4ZOH=87365_1e2Mgal=1067_1e2logn=-338_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.248_logsfr=0.495_1e4ZOH=89538_1e2Mgal=1024_1e2logn=-248_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-2.374_logsfr=-1.005_1e4ZOH=69560_1e2Mgal=685_1e2logn=-142_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.179_logsfr=0.712_1e4ZOH=89197_1e2Mgal=1027_1e2logn=-255_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-0.012_logsfr=1.381_1e4ZOH=88239_1e2Mgal=1069_1e2logn=-320_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-0.410_logsfr=1.543_1e4ZOH=86251_1e2Mgal=1079_1e2logn=-383_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-2.724_logsfr=1.489_1e4ZOH=66055_1e2Mgal=1017_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-0.304_logsfr=1.688_1e4ZOH=86777_1e2Mgal=1102_1e2logn=-411_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.287_logsfr=1.305_1e4ZOH=86865_1e2Mgal=1050_1e2logn=-323_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=-0.071_logsfr=1.150_1e4ZOH=87945_1e2Mgal=1037_1e2logn=-283_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=-0.356_logsfr=0.388_1e4ZOH=86521_1e2Mgal=948_1e2logn=-225_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.345_logsfr=1.187_1e4ZOH=90024_1e2Mgal=1092_1e2logn=-326_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=0.444_logsfr=0.907_1e4ZOH=90520_1e2Mgal=1112_1e2logn=-364_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=-0.161_logsfr=0.704_1e4ZOH=87492_1e2Mgal=989_1e2logn=-245_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.014_logsfr=-0.226_1e4ZOH=88372_1e2Mgal=945_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.577_logsfr=1.048_1e4ZOH=85412_1e2Mgal=1008_1e2logn=-295_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-2.921_logsfr=1.165_1e4ZOH=64090_1e2Mgal=970_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=0.090_logsfr=1.146_1e4ZOH=88750_1e2Mgal=1051_1e2logn=-286_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-0.320_logsfr=1.064_1e4ZOH=86699_1e2Mgal=1016_1e2logn=-283_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=-0.246_logsfr=0.809_1e4ZOH=87069_1e2Mgal=992_1e2logn=-253_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-0.510_logsfr=0.910_1e4ZOH=85749_1e2Mgal=991_1e2logn=-270_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.722_logsfr=0.702_1e4ZOH=76076_1e2Mgal=930_1e2logn=-307_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=0.155_logsfr=1.234_1e4ZOH=89074_1e2Mgal=1066_1e2logn=-299_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=0.149_logsfr=1.428_1e4ZOH=89043_1e2Mgal=1083_1e2logn=-324_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=-0.423_logsfr=0.484_1e4ZOH=86183_1e2Mgal=952_1e2logn=-231_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=0.398_logsfr=1.315_1e4ZOH=90290_1e2Mgal=1116_1e2logn=-376_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.228_logsfr=1.458_1e4ZOH=81024_1e2Mgal=1047_1e2logn=-416_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.311_logsfr=1.298_1e4ZOH=80191_1e2Mgal=1023_1e2logn=-387_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-0.851_logsfr=1.116_1e4ZOH=84046_1e2Mgal=1011_1e2logn=-323_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-1.044_logsfr=0.943_1e4ZOH=82860_1e2Mgal=983_1e2logn=-302_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.587_logsfr=0.878_1e4ZOH=77426_1e2Mgal=957_1e2logn=-320_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-1.461_logsfr=0.418_1e4ZOH=78685_1e2Mgal=900_1e2logn=-246_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=-1.755_logsfr=-1.786_1e4ZOH=75753_1e2Mgal=688_1e2logn=8_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=3.052_feh=-0.195_logsfr=1.884_1e4ZOH=87326_1e2Mgal=1132_1e2logn=-464_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-0.092_logsfr=1.286_1e4ZOH=87839_1e2Mgal=1053_1e2logn=-306_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=0.125_logsfr=1.582_1e4ZOH=88923_1e2Mgal=1101_1e2logn=-361_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=0.068_logsfr=1.802_1e4ZOH=88642_1e2Mgal=1129_1e2logn=-432_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.955_logsfr=0.419_1e4ZOH=73751_1e2Mgal=886_1e2logn=-288_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-2.860_logsfr=1.258_1e4ZOH=64695_1e2Mgal=983_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-3.235_logsfr=0.737_1e4ZOH=60945_1e2Mgal=907_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=-2.140_logsfr=-1.086_1e4ZOH=71896_1e2Mgal=687_1e2logn=-135_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=-1.899_logsfr=-1.328_1e4ZOH=74309_1e2Mgal=686_1e2logn=-115_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=10.000_feh=-2.799_logsfr=1.358_1e4ZOH=65313_1e2Mgal=998_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.022_logsfr=1.637_1e4ZOH=88192_1e2Mgal=1103_1e2logn=-382_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.090_feh=-0.190_logsfr=1.183_1e4ZOH=87347_1e2Mgal=1036_1e2logn=-294_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.101_feh=-0.102_logsfr=0.610_1e4ZOH=87789_1e2Mgal=986_1e2logn=-239_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=4.644_feh=-1.147_logsfr=1.644_1e4ZOH=81827_1e2Mgal=1076_1e2logn=-452_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=2.487_feh=-0.101_logsfr=1.520_1e4ZOH=87793_1e2Mgal=1084_1e2logn=-357_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.548_feh=0.331_logsfr=1.555_1e4ZOH=89955_1e2Mgal=1120_1e2logn=-388_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.010_feh=0.385_logsfr=0.243_1e4ZOH=90224_1e2Mgal=1059_1e2logn=0_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.798_feh=0.086_logsfr=1.338_1e4ZOH=88731_1e2Mgal=1068_1e2logn=-308_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.496_feh=-1.815_logsfr=-1.497_1e4ZOH=75148_1e2Mgal=686_1e2logn=-106_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=0.079_logsfr=0.941_1e4ZOH=88695_1e2Mgal=1032_1e2logn=-267_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=1.300_feh=0.372_logsfr=1.427_1e4ZOH=90160_1e2Mgal=1117_1e2logn=-381_logpool=6.60_igimf_zams_sample.parquet'),
#  PosixPath('/home/lucasmdesa/Documents/GitHub/BOSSA/data/zams_grids/12x10_2222_zams_grid/z=0.857_feh=0.336_logsfr=0.956_1e4ZOH=89978_1e2Mgal=1074_1e2logn=-297_logpool=6.60_igimf_zams_sample.parquet')]

# %%
def normalize_igimf(igimf_x, igimf_y, sample_x, sample_y):
    igimf_spline = UnivariateSpline(igimf_x, igimf_y, k=3)
    sample_spline = UnivariateSpline(sample_x, sample_y, k=3)
    
    igimf_area = igimf_spline.integral(0.8, 150)
    sample_area = sample_spline.integral(0.8, 150)
    
    print(sample_area, igimf_area)
    
    igimf_norm = sample_area/igimf_area
    
    return igimf_norm

# %%
def kroupa_imf(m):
    if m < 0.5:
        return 2*m**-1.3
    else:
        return m**-2.3

# %%
def plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 10), legend=True, kroupa=True, mindex=[0], c=None, title=True):
    m1arr = np.sort(sample_df['Mass_ZAMS1_Found'].to_numpy())
    m2arr = np.sort(sample_df['Mass_ZAMS2_Found'].to_numpy())
    m3arr = np.sort(sample_df['Mass_ZAMS3_Found'].to_numpy())
    m4arr = np.sort(sample_df['Mass_ZAMS4_Found'].to_numpy())
    m5arr = np.sort(sample_df['Mass_ZAMS5_Found'].to_numpy())
    m12arr = np.sort(np.concatenate((m1arr, m2arr)))
    mall_arr = np.sort(np.concatenate((m1arr, m2arr, m3arr, m4arr, m5arr)))
    
    m2arr = m2arr[m2arr >= 0.8]
    m3arr = m3arr[m3arr >= 0.8]
    m4arr = m4arr[m4arr >= 0.8]
    m5arr = m5arr[m5arr >= 0.8]
    m12arr = m12arr[m12arr >= 0.8]
    mall_arr = mall_arr[mall_arr >= 0.8]
    

    
    highmass_frac_m1 = len(m1arr[m1arr>=16])/len(m1arr)
    highmass_frac_m2 = len(m2arr[m2arr>=16])/len(m2arr)
    
    sfr = 10**float(sample_descr_dict['logsfr'])
    feh = float(sample_descr_dict['feh'])
    
    igimf = IGIMF(sfr, feh)
    igimf.set_clusters()
    igimf_masses = np.concatenate((np.logspace(np.log10(0.8), np.log10(149.9), 20), [150]))
    igimfs = np.array([igimf.imf(mass) for mass in igimf_masses])
    
    igimf_ip = UnivariateSpline(igimf_masses, igimfs)
    igimf_norm = igimf_ip.integral(5, 150)
    #ax.plot(m1_IMF[:,0][::2], m1_IMF[:,1][::2], 'r-', label='M1')
    #ax.plot(m2_IMF[:,0][::2], m2_IMF[:,1][::2], 'b-', label='M2')
   #ax.plot(m12_IMF[:,0][::2], m12_IMF[:,1][::2], 'g-', label='M1+M2')
   
    m1h, m1b = np.histogram(m1arr, density=True, bins=bins)
    m2h, m2b = np.histogram(m2arr, density=True, bins=bins)
    m3h, m3b = np.histogram(m3arr, density=True, bins=bins)
    m4h, m4b = np.histogram(m4arr, density=True, bins=bins)
    m5h, m5b = np.histogram(m5arr, density=True, bins=bins)
    m12h, m12b = np.histogram(m12arr, density=True, bins=bins)
    mall_h, mall_b = np.histogram(mall_arr, density=True, bins=bins)
    
    m1c = np.array([(m1b0+m1b1)/2 for m1b0, m1b1 in zip(m1b[:-1], m1b[0:])])
    m2c = np.array([(m2b0+m2b1)/2 for m2b0, m2b1 in zip(m2b[:-1], m2b[0:])])
    m3c = np.array([(m3b0+m3b1)/2 for m3b0, m3b1 in zip(m3b[:-1], m3b[0:])])
    m4c = np.array([(m4b0+m4b1)/2 for m4b0, m4b1 in zip(m4b[:-1], m4b[0:])])
    m5c = np.array([(m5b0+m5b1)/2 for m5b0, m5b1 in zip(m5b[:-1], m5b[0:])])
    m12c = np.array([(m12b0+m12b1)/2 for m12b0, m12b1 in zip(m12b[:-1], m12b[0:])])
    mall_c = np.array([(mall_b0+mall_b1)/2 for mall_b0, mall_b1 in zip(mall_b[:-1], mall_b[0:])])
    
    mplots = [[m1b, m1h, 'r', '--', 2, r'$m_1$'],
             [m2b, m2h, 'b', '--', 2, r'$m_2$'],
             [m3b, m3h, 'm', '--', 2, r'$m_3$'],
             [m4b, m4h, 'y', '--', 2, r'$m_4$'],
             [m5b, m5h, 'c', '--', 2, r'$m_5$'],
             [m12b, m12h, 'g', '-', 3, r'$m_1+m2$'],
             [mall_b, mall_h, 'g', '-', 3, r'all $m_i$']]
    for index in mindex:
        mb, mh, color, ls, lw, label = mplots[index]
        if c is not None:
            color = c
        #ax.plot(mc, mh, c=color, ls=ls, label=label, lw=lw)
        ax.stairs(mh, mb, color=color, ls=ls, lw=lw, label=label)
    #ax.plot(m1c, m1h, 'r:', label=r'$m_1$', lw=3)
    #ax.plot(m2c, m2h, 'b:', label=r'$m_2$', lw=3)
    #ax.plot(m3c, m3h, 'm:', label=r'$m_3$', lw=3)
    #ax.plot(m4c, m4h, 'y:', label=r'$m_4$', lw=3)
    #ax.plot(m5c, m5h, 'c:', label=r'$m_5$', lw=3)
    #ax.plot(m12c, m12h, 'g--', label=r'$m_1+m_2$', lw=3)
    #ax.plot(mall_c, mall_h, 'g-', label=r'$\sum_{i=1}^5 m_i$', lw=3)
    
#    sns.histplot(sample_df, x='Mass_ZAMS1_Found', stat='frequency', color='r', label='m1')
#    sns.histplot(sample_df, x='Mass_ZAMS2_Found', stat='frequency', color='b', label='m2')
#    sns.histplot(x=m12arr, stat='frequency', color='g', label='m1+m2')
#    sns.histplot(x=igimf_masses, stat='frequency', color='m', label='IGIMF')
    if not kroupa:
        color = 'k'
        if c is not None:
            color = c
        ax.plot(igimf_masses, igimfs/igimf_norm, color=color, ls='-', label='IGIMF', lw=2)
    
    if kroupa:
        kroupa_masses = np.logspace(np.log10(0.8), np.log10(150), 10)
        kroupa_imfs = np.array([kroupa_imf(m) for m in kroupa_masses])
        kroupa_ip = UnivariateSpline(kroupa_masses, kroupa_imfs)
        kroupa_norm = kroupa_ip.integral(0.08, 150)/10
        ax.plot(kroupa_masses, kroupa_imfs/kroupa_norm, 'k--', label='Kroupa', lw=3)
    if legend:
        ax.legend(loc='upper right', bbox_to_anchor=(1,1), frameon=False)
    
    if title:
        ax.set_title(f'$\log \mathrm{{SFR}} = {sample_descr_dict["logsfr"]}, \mathrm{{[Fe/H]}} = {sample_descr_dict["feh"]}$')
    
    #ax.text(0.2, 0.1, f'M1 hmass frac = {highmass_frac_m1:.4f} \n M2 hmass frac = {highmass_frac_m2:.4f}', transform=ax.transAxes)

    #ax.set_ylim(1e0, 1e8)

    ax.set_xscale('log')
    ax.set_yscale('log')
    
    return mplots
# Out:
# <>:93: SyntaxWarning: invalid escape sequence '\l'
# <>:93: SyntaxWarning: invalid escape sequence '\m'
# <>:93: SyntaxWarning: invalid escape sequence '\l'
# <>:93: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_697581/1358245172.py:93: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_title(f'$\log \mathrm{{SFR}} = {sample_descr_dict["logsfr"]}, \mathrm{{[Fe/H]}} = {sample_descr_dict["feh"]}$')
# /tmp/ipykernel_697581/1358245172.py:93: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_title(f'$\log \mathrm{{SFR}} = {sample_descr_dict["logsfr"]}, \mathrm{{[Fe/H]}} = {sample_descr_dict["feh"]}$')

# %%
def plot_cdf(ax, sample_df, sample_descr_dict):
    m1arr = np.sort(sample_df['Mass_ZAMS1_Found'].to_numpy())
    m2arr = np.sort(sample_df['Mass_ZAMS2_Found'].to_numpy())
    m3arr = np.sort(sample_df['Mass_ZAMS3_Found'].to_numpy())
    m4arr = np.sort(sample_df['Mass_ZAMS4_Found'].to_numpy())
    m5arr = np.sort(sample_df['Mass_ZAMS5_Found'].to_numpy())
    m12arr = np.sort(np.concatenate((m1arr, m2arr)))
    mall_arr = np.sort(np.concatenate((m1arr, m2arr, m3arr, m4arr, m5arr)))
    
    m2arr = m2arr[m2arr >= 0.8]
    m3arr = m3arr[m3arr >= 0.8]
    m4arr = m4arr[m4arr >= 0.8]
    m5arr = m5arr[m5arr >= 0.8]
    m12arr = m12arr[m12arr >= 0.8]
    mall_arr = mall_arr[mall_arr >= 0.8]
        
    sfr = 10**float(sample_descr_dict['logsfr'])
    feh = float(sample_descr_dict['feh'])
        
    #plt.hist(m1arr, density=True, cumulative=True, label='M1', histtype='step', alpha=1, color='r')
    #plt.hist(m2arr, density=True, cumulative=True, label='M1', histtype='step', alpha=1, color='b')
    #plt.hist(m12arr, density=True, cumulative=True, label='M1', histtype='step', alpha=1, color='g')
    sns.ecdfplot(m1arr, label='M1', color='r', linestyle=':', ax=ax)
    sns.ecdfplot(m2arr, label='M2', color='b', linestyle=':', ax=ax)
    sns.ecdfplot(m12arr, label='M1+M2', color='g', linestyle='--', ax=ax)
    sns.ecdfplot(mall_arr, label=r'$\sum_{i=1}^5 m_i$', color='g', linestyle='-', ax=ax)
    
    igimf = IGIMF(sfr, feh)
    igimf.set_clusters()
    igimf_sampling = RandomSampling(igimf)
    igimf_sampling.compute_imf()
    igimf_sample = igimf_sampling.get_sample(0.8, 150, 100000)
    igimf_sample = igimf_sample[igimf_sample>=0.8]
    sns.ecdfplot(igimf_sample, label='IGIMF', color='m', ax=ax)
    
    k_imf = Star(sfr*1e7, feh, invariant=True)
    k_imf.get_mmax_k()
    k_imf_sampling = RandomSampling(k_imf)
    k_imf_sampling.compute_imf()
    k_imf_sample = k_imf_sampling.get_sample(0.8, 150, 100000)
    k_imf_sample = k_imf_sample[k_imf_sample>=0.8]
    sns.ecdfplot(k_imf_sample, label='Kroupa', color='m', linestyle='--', ax=ax)
    
    ax.legend()
    
    ax.tick_params(axis='both', labelsize=14)

    ax.set_title(f'logSFR = {sample_descr_dict["logsfr"]}, [Fe/H] = {sample_descr_dict["feh"]}', fontsize=14)

    ax.set_xscale('log')

# %% [markdown]
# ## Redshift plot

# %% [markdown]
# #### IMF Grid

# %%
onlybin_sample_paths_dict = {}
for path in onlybin_sample_paths:
    z = float(path.name.split('_')[0].split('=')[1])
    if z not in onlybin_sample_paths_dict:
        onlybin_sample_paths_dict[z] = []
    onlybin_sample_paths_dict[z].append(path)

# %%
allmult_sample_paths_dict = {}
for path in allmult_sample_paths:
    z = float(path.name.split('_')[0].split('=')[1])
    if z not in allmult_sample_paths_dict:
        allmult_sample_paths_dict[z] = []
    allmult_sample_paths_dict[z].append(path)

# %%
onlybin_canon_sample_paths_dict = {}
for path in onlybin_canon_sample_paths:
    z = float(path.name.split('_')[0].split('=')[1])
    if z not in onlybin_canon_sample_paths_dict:
        onlybin_canon_sample_paths_dict[z] = []
    onlybin_canon_sample_paths_dict[z].append(path)

# %%
allmult_canon_sample_paths_dict = {}
for path in allmult_canon_sample_paths:
    z = float(path.name.split('_')[0].split('=')[1])
    if z not in allmult_canon_sample_paths_dict:
        allmult_canon_sample_paths_dict[z] = []
    allmult_canon_sample_paths_dict[z].append(path)

# %%
for z in onlybin_sample_paths_dict:
    unsorted_paths = onlybin_sample_paths_dict[z]
    unsorted_sfrs = [float(path.name.split('_')[2].split('=')[1]) for path in unsorted_paths]
    sorted_indexes = np.argsort(unsorted_sfrs)
    sorted_paths = np.array(unsorted_paths)[sorted_indexes]
    onlybin_sample_paths_dict[z] = sorted_paths

# %%
for z in allmult_sample_paths_dict:
    unsorted_paths = allmult_sample_paths_dict[z]
    unsorted_sfrs = [float(path.name.split('_')[2].split('=')[1]) for path in unsorted_paths]
    sorted_indexes = np.argsort(unsorted_sfrs)
    sorted_paths = np.array(unsorted_paths)[sorted_indexes]
    allmult_sample_paths_dict[z] = sorted_paths

# %%
for z in onlybin_canon_sample_paths_dict:
    unsorted_paths = onlybin_canon_sample_paths_dict[z]
    unsorted_sfrs = [float(path.name.split('_')[2].split('=')[1]) for path in unsorted_paths]
    sorted_indexes = np.argsort(unsorted_sfrs)
    sorted_paths = np.array(unsorted_paths)[sorted_indexes]
    onlybin_canon_sample_paths_dict[z] = sorted_paths

# %%
for z in allmult_canon_sample_paths_dict:
    unsorted_paths = allmult_canon_sample_paths_dict[z]
    unsorted_sfrs = [float(path.name.split('_')[2].split('=')[1]) for path in unsorted_paths]
    sorted_indexes = np.argsort(unsorted_sfrs)
    sorted_paths = np.array(unsorted_paths)[sorted_indexes]
    allmult_canon_sample_paths_dict[z] = sorted_paths

# %%
from matplotlib.lines import Line2D

# %%
plot_zs = sorted(list(onlybin_sample_paths_dict.keys()))[:9]
onlybin_plot_fehs = []
allmult_plot_fehs = []

for z in plot_zs:
        onlybin_sample_paths_ = onlybin_sample_paths_dict[z]   
        allmult_sample_paths_ = allmult_sample_paths_dict[z]   
        for path in onlybin_sample_paths_[:-1]:
                sample_descr = path.name.split('_')[:-3]

                sample_descr_dict = {}
                for attr in sample_descr:
                    key, value = attr.split('=')
                    sample_descr_dict[key] = value
                onlybin_plot_fehs.append(sample_descr_dict['feh'])
        for path in allmult_sample_paths_[:-1]:
                sample_descr = path.name.split('_')[:-3]

                sample_descr_dict = {}
                for attr in sample_descr:
                    key, value = attr.split('=')
                    sample_descr_dict[key] = value
                allmult_plot_fehs.append(sample_descr_dict['feh'])
onlybin_plot_fehs = np.array(onlybin_plot_fehs, np.float32)
allmult_plot_fehs = np.array(allmult_plot_fehs, np.float32)

# %%
onlybin_min_plot_feh = onlybin_plot_fehs.min()
onlybin_max_plot_feh = onlybin_plot_fehs.max()
onlybin_norm_plot_feh = onlybin_max_plot_feh - onlybin_min_plot_feh

# %%
allmult_min_plot_feh = allmult_plot_fehs.min()
allmult_max_plot_feh = allmult_plot_fehs.max()
allmult_norm_plot_feh = allmult_max_plot_feh - allmult_min_plot_feh

# %%
min_plot_feh = min(onlybin_min_plot_feh, allmult_min_plot_feh)
max_plot_feh = max(onlybin_max_plot_feh, allmult_max_plot_feh)
norm_plot_feh = max_plot_feh - min_plot_feh

# %%
plot_zs = np.array(plot_zs)

# %%
fig, axes_ = plt.subplots(2, 3, figsize=(24, 12), sharex=True, sharey=True)
axes = axes_#.flatten()
fig.subplots_adjust(hspace=0, wspace=0)
rect = fig.patch
rect.set_facecolor('white')


for z, ax in zip(plot_zs[[0,5,8]], axes[0]):
    sample_paths_ = onlybin_sample_paths_dict[z]   
    
    for b in np.logspace(-5, 5, 10):
        ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
        #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
        ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
    
    counter = 0
    for path in sample_paths_[[5]]:
        sample_descr = path.name.split('_')[:-3]

        sample_descr_dict = {}
        for attr in sample_descr:
            key, value = attr.split('=')
            sample_descr_dict[key] = value
            
        feh = np.float32(sample_descr_dict['feh'])
        #c = cm.viridis(counter/9)
        c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

        sample_df = pd.read_parquet(path, engine='pyarrow')

        legend = False
        if counter == 0:
            legend = True
            
        plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[0,1,-1], c=None, title=False)
        counter += 1
        
         #   for ax in axes[-1, :]:
        #ax.set_xlabel(r'$\log\left(M/\mathrm{M}_\odot\right)$', fontsize=18)
        #ax.set_xticks([1e-1, 1e0, 1e1, 1e2])
        #ax.set_xticklabels(['-1', '0', '1', '2'])
    ax.set_xlim(0.8, 150)
    ax.set_ylim(1e-5, 2e0)

    #for ax in axes[:, 0]:
        #ax.set_ylabel(, fontsize=18)
        #ax.set_yticks([1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8])
        #ax.set_yticklabels(['0', '1', '2', '3', '4', '5', '6', '7', '8'])
        
    z_descr_str = ''.join([f'$z_\mathrm{{ZAMS}}={z:.2f}$',
                             f'$\mathrm{{[Fe/H]}}={feh:.2f}$'])
    #z_descr = ax.text(0.95, 0.9, z_descr_str, ha='right', va='top', transform=ax.transAxes, fontsize=30)
    #z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
    fig.text(0.5, 1.02, z_descr_str, ha='center', va='bottom', transform=ax.transAxes, fontsize=30)
    
for z, ax in zip(plot_zs[[0,5,8]], axes[1]):
    sample_paths_ = allmult_sample_paths_dict[z]   
    
    for b in np.logspace(-5, 5, 10):
        ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
        #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
        ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
    
    counter = 0
    for path in sample_paths_[[5]]:
        sample_descr = path.name.split('_')[:-3]

        sample_descr_dict = {}
        for attr in sample_descr:
            key, value = attr.split('=')
            sample_descr_dict[key] = value
            
        feh = np.float32(sample_descr_dict['feh'])
        #c = cm.viridis(counter/9)
        c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

        sample_df = pd.read_parquet(path, engine='pyarrow')

        legend = False
        if counter == 0:
            legend = True
            
        plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[0,1,2,3,4,-1], c=None, title=False)
        counter += 1
        

 #   for ax in axes[-1, :]:
        #ax.set_xlabel(r'$\log\left(M/\mathrm{M}_\odot\right)$', fontsize=18)
        #ax.set_xticks([1e-1, 1e0, 1e1, 1e2])
        #ax.set_xticklabels(['-1', '0', '1', '2'])
    ax.set_xlim(0.8, 150)
    ax.set_ylim(1e-5, 2e0)

    #for ax in axes[:, 0]:
        #ax.set_ylabel(, fontsize=18)
        #ax.set_yticks([1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8])
        #ax.set_yticklabels(['0', '1', '2', '3', '4', '5', '6', '7', '8'])
        
    #z_descr_str = '\n'.join([f'$z_\mathrm{{ZAMS}}={z:.2f}$',
    #                         f'$\mathrm{{[Fe/H]}}={feh:.2f}$'])
    #z_descr = ax.text(0.95, 0.95, z_descr_str, ha='right', va='top', transform=ax.transAxes, fontsize=30)
    #z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
    
    
fig.text(0.04, 0.45, '$\\log\\left[\\xi_\\mathrm{gw}\\,\\left(m|\\mathrm{[Fe/H]},\\mathrm{SFR}\\right)/(\\mathrm{M}_\\odot^{-1})\\right]$', 
         ha='right', va='center', rotation=90, transform=fig.transFigure, fontsize=36)
fig.text(0.5, 0.05, '$\\log\\left(m/\\mathrm{M}_\\odot\\right)$', ha='center', va='top', fontsize=36)

#fig.text(0.5, 1, 'All multiples', ha='center', va='bottom', transform=axes[0,1].transAxes, fontsize=36)
#fig.text(0.5, 1, 'All multiples', ha='center', va='bottom', transform=axes[0,2].transAxes, fontsize=36)
fig.text(-0.15, 0.5, 'Only binaries', ha='right', va='center', rotation=90, transform=axes[0,0].transAxes, fontsize=36)
fig.text(-0.15, 0.5, 'All multiples', ha='right', va='center', rotation=90, transform=axes[1,0].transAxes, fontsize=36)

for ax in axes.flatten():
    ax.set_xlim(0.8, 150)
    ax.tick_params(labelsize=30)
    ax.set_ylim(7e-6, 2e0)

mplots = [['r', '--', r'$m_1$'],
         ['b', '--', r'$m_2$'],
         ['m', '--', r'$m_3$'],
         ['y', '--', r'$m_4$'],
         ['c', '--', r'$m_5$'],
         ['g', '-', r'all $m_i$']]

for ax in [axes[0,0]]:
    handles = []
    for mplot in mplots:
        sample_line = Line2D([0], [0], label=mplot[2], color=mplot[0], linestyle=mplot[1])
        handles.append(sample_line)
    igimf_line = Line2D([0], [0], label='IGIMF', color='k',  linestyle='-')
    kroupa_line = Line2D([0], [0], label='Kroupa', color='k', linestyle='--')
    handles += [kroupa_line, igimf_line]
    ax.legend(handles=handles, frameon=True, loc='lower left', bbox_to_anchor=(0,1.15), ncol=4, edgecolor='black', fancybox=False, borderpad=0.2)
    
plt.savefig(FIGURE_FOLDER/f'imf_sampling_variations_1e6.pdf', bbox_inches='tight')
plt.savefig(FIGURE_FOLDER/f'imf_sampling_variations_1e6.png', bbox_inches='tight')
# Out:
# <>:50: SyntaxWarning: invalid escape sequence '\m'
# <>:51: SyntaxWarning: invalid escape sequence '\m'
# <>:50: SyntaxWarning: invalid escape sequence '\m'
# <>:51: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_697581/1062742012.py:50: SyntaxWarning: invalid escape sequence '\m'
#   z_descr_str = ''.join([f'$z_\mathrm{{ZAMS}}={z:.2f}$',
# /tmp/ipykernel_697581/1062742012.py:51: SyntaxWarning: invalid escape sequence '\m'
#   f'$\mathrm{{[Fe/H]}}={feh:.2f}$'])
# /home/lucasmdesa/anaconda3/envs/bossa/lib/python3.12/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /home/lucasmdesa/anaconda3/envs/bossa/lib/python3.12/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /home/lucasmdesa/anaconda3/envs/bossa/lib/python3.12/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
fig, axes_ = plt.subplots(2, 2, figsize=(24, 12), sharex=True, sharey=True)
axes = axes_#.flatten()
fig.subplots_adjust(hspace=0, wspace=0)
rect = fig.patch
rect.set_facecolor('white')

z = plot_zs[3]

######### Q CORR ONLYBIN PLOT ###############
sample_paths_ = onlybin_sample_paths_dict[z]
ax = axes[1,0]

for b in np.logspace(-5, 5, 10):
    ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
    ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)

counter = 0
for path in sample_paths_[[5]]:
    sample_descr = path.name.split('_')[:-3]

    sample_descr_dict = {}
    for attr in sample_descr:
        key, value = attr.split('=')
        sample_descr_dict[key] = value

    feh = np.float32(sample_descr_dict['feh'])
    c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

    sample_df = pd.read_parquet(path, engine='pyarrow')

    legend = False
    if counter == 0:
        legend = True

    corr_onlybin_mplots = plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[0,1,-1], c=None, title=False)
    counter += 1

ax.set_xlim(0.8, 150)
ax.set_ylim(1e-5, 2e0)

######### Q NOCORR ONLYBIN PLOT ###############
sample_paths_ = onlybin_canon_sample_paths_dict[z]
ax = axes[0,0]

for b in np.logspace(-5, 5, 10):
    ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
    ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)

counter = 0
for path in sample_paths_[[5]]:
    sample_descr = path.name.split('_')[:-3]

    sample_descr_dict = {}
    for attr in sample_descr:
        key, value = attr.split('=')
        sample_descr_dict[key] = value

    feh = np.float32(sample_descr_dict['feh'])
    c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

    sample_df = pd.read_parquet(path, engine='pyarrow')

    legend = False
    if counter == 0:
        legend = True

    nocorr_onlybin_mplots = plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=True, mindex=[0,1,-1], c=None, title=False)
    counter += 1

ax.set_xlim(0.8, 150)
ax.set_ylim(1e-5, 2e0)

#################### Q CORR ALLMULT PLOT ################
sample_paths_ = allmult_sample_paths_dict[z]   
ax = axes[1,1]

for b in np.logspace(-5, 5, 10):
    ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
    ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)

counter = 0
for path in sample_paths_[[5]]:
    sample_descr = path.name.split('_')[:-3]

    sample_descr_dict = {}
    for attr in sample_descr:
        key, value = attr.split('=')
        sample_descr_dict[key] = value

    feh = np.float32(sample_descr_dict['feh'])
    #c = cm.viridis(counter/9)
    c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

    sample_df = pd.read_parquet(path, engine='pyarrow')

    legend = False
    if counter == 0:
        legend = True

    corr_allmult_mplots = plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[0,1,2,3,4,-1], c=None, title=False)
    counter += 1

ax.set_xlim(0.8, 150)
ax.set_ylim(1e-5, 2e0)

#################### Q NOCORR ALLMULT PLOT ################
sample_paths_ = allmult_canon_sample_paths_dict[z]   
ax = axes[0,1]

for b in np.logspace(-5, 5, 10):
    ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))  
    ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)

counter = 0
for path in sample_paths_[[5]]:
    sample_descr = path.name.split('_')[:-3]

    sample_descr_dict = {}
    for attr in sample_descr:
        key, value = attr.split('=')
        sample_descr_dict[key] = value

    feh = np.float32(sample_descr_dict['feh'])
    c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

    sample_df = pd.read_parquet(path, engine='pyarrow')

    legend = False
    if counter == 0:
        legend = True

    nocorr_allmult_mplots = plot_imf(ax, sample_df, sample_descr_dict, bins=np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=True, mindex=[0,1,2,3,4,-1], c=None, title=False)
    counter += 1

z_descr_str = '\n'.join([f'$z_\mathrm{{ZAMS}}={z:.2f}$',
                         f'$\mathrm{{[Fe/H]}}={feh:.2f}$'])
z_descr = ax.text(0.95, 0.95, z_descr_str, ha='right', va='top', transform=ax.transAxes, fontsize=30)
z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))

############ FINAL DETAILS #############

for ax in axes.flatten():
    ax.set_xlim(0.8, 150)
    ax.set_ylim(4e-6, 2e0)
    
    xticks = ax.get_xticks()
    xticklabels = [f'{np.log10(t):.0f}' for t in xticks]
    ax.set_xticklabels(xticklabels)
    
    yticks = ax.get_yticks()
    yticklabels = [f'{np.log10(t):.0f}' for t in yticks]
    ax.set_yticklabels(yticklabels)
    
    ax.tick_params(labelsize=30)
    
fig.text(0.5, 1, 'Only Binaries (OB)', ha='center', va='bottom', transform=axes[0,0].transAxes, fontsize=36)
fig.text(0.5, 1, 'All Multiples (AM)', ha='center', va='bottom', transform=axes[0,1].transAxes, fontsize=36)
fig.text(1.02, 0.5, 'Varying', ha='left', va='center', rotation=-90, transform=axes[1,1].transAxes, fontsize=36)
fig.text(1.02, 0.5, 'Invariant', ha='left', va='center', rotation=-90, transform=axes[0,1].transAxes, fontsize=36)

fig.text(0.1, 0.5, '$\\log\\left[\\xi_\\mathrm{gw}\\,(m)/(\\mathrm{a.u.})\\right]$', 
         ha='right', va='center', rotation=90, transform=fig.transFigure, fontsize=36)
fig.text(0.5, 0.05, '$\\log\\left(m/\\mathrm{M}_\\odot\\right)$', ha='center', va='top', fontsize=36)

mplots = [['r', '--', r'$m_1$'],
         ['b', '--', r'$m_2$'],
         ['m', '--', r'$m_3$'],
         ['y', '--', r'$m_4$'],
         ['c', '--', r'$m_5$'],
         ['g', '-', r'all $m_i$']]

for ax in [axes[0,0]]:
    handles = []
    for mplot in mplots:
        sample_line = Line2D([0], [0], label=mplot[2], color=mplot[0], linestyle=mplot[1])
        handles.append(sample_line)
    igimf_line = Line2D([0], [0], label='J18 IMF', color='k',  linestyle='-')
    kroupa_line = Line2D([0], [0], label='K01 IMF', color='k', linestyle='--')
    handles += [kroupa_line, igimf_line]
    ax.legend(handles=handles, frameon=True, loc='lower left', bbox_to_anchor=(0,1.1), ncol=4, edgecolor='black', fancybox=False, borderpad=0.2)
    
plt.savefig(FIGURE_FOLDER/f'imf_sampling_comparison_1e6.pdf', bbox_inches='tight')
plt.savefig(FIGURE_FOLDER/f'imf_sampling_comparison_1e6.eps', bbox_inches='tight')
plt.savefig(FIGURE_FOLDER/f'imf_sampling_comparison_1e6.png', bbox_inches='tight')
# Out:
# <>:135: SyntaxWarning: invalid escape sequence '\m'
# <>:136: SyntaxWarning: invalid escape sequence '\m'
# <>:135: SyntaxWarning: invalid escape sequence '\m'
# <>:136: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_697581/188027204.py:135: SyntaxWarning: invalid escape sequence '\m'
#   z_descr_str = '\n'.join([f'$z_\mathrm{{ZAMS}}={z:.2f}$',
# /tmp/ipykernel_697581/188027204.py:136: SyntaxWarning: invalid escape sequence '\m'
#   f'$\mathrm{{[Fe/H]}}={feh:.2f}$'])
# /home/lucasmdesa/anaconda3/envs/bossa/lib/python3.12/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /home/lucasmdesa/anaconda3/envs/bossa/lib/python3.12/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /tmp/ipykernel_697581/188027204.py:148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# /tmp/ipykernel_697581/188027204.py:152: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(yticklabels)
# /tmp/ipykernel_697581/188027204.py:148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# /tmp/ipykernel_697581/188027204.py:152: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(yticklabels)
# /tmp/ipykernel_697581/188027204.py:148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# /tmp/ipykernel_697581/188027204.py:152: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(yticklabels)
# /tmp/ipykernel_697581/188027204.py:148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# /tmp/ipykernel_697581/188027204.py:152: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(yticklabels)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
from scipy.stats import linregress

# %%
samples_mplots = {'corr_onlybin': corr_onlybin_mplots, 
                  'nocorr_onlybin': nocorr_onlybin_mplots,
                  'corr_allmult': corr_allmult_mplots,
                  'nocorr_allmult': nocorr_allmult_mplots}
mplot_array_labels = ['m1', 'm2', 'm3', 'm4', 'm5', 'm21', 'mall']

for sample_label in samples_mplots:
    mplots = samples_mplots[sample_label]
    for mplot, mplot_label in zip(mplots, mplot_array_labels):
        mb, mh, color, ls, lw, label = mplot
        mb = np.log10(mb)
        mc = np.array([(mb0+mb1)/2 for mb0, mb1 in zip(mb[:-1], mb[1:])])
        mh = np.log10(mh)
        m10_i = np.searchsorted(mc, 1)
        slope, *_ = linregress(mc, mh)
        slope1, *_ = linregress(mc[:m10_i], mh[:m10_i])
        slope2, *_ = linregress(mc[m10_i:], mh[m10_i:])
        print(f'In {sample_label} label, {mplot_label} is best fit by a power-law {slope:.2f}, or {slope1:.2f} up to {10**mc[m10_i]:.2f} Mo and {slope2:.2f} above.')
    print('')
# Out:
# In corr_onlybin label, m1 is best fit by a power-law -1.44, or -1.84 up to 10.95 Mo and -0.89 above.
# In corr_onlybin label, m2 is best fit by a power-law -1.52, or -1.49 up to 10.95 Mo and -2.03 above.
# In corr_onlybin label, m3 is best fit by a power-law nan, or nan up to 10.95 Mo and nan above.
# In corr_onlybin label, m4 is best fit by a power-law nan, or nan up to 10.95 Mo and nan above.
# In corr_onlybin label, m5 is best fit by a power-law nan, or nan up to 10.95 Mo and nan above.
# In corr_onlybin label, m21 is best fit by a power-law -1.44, or -1.74 up to 10.95 Mo and -1.17 above.
# In corr_onlybin label, mall is best fit by a power-law -1.44, or -1.74 up to 10.95 Mo and -1.17 above.
#
# In nocorr_onlybin label, m1 is best fit by a power-law -2.32, or -2.35 up to 10.95 Mo and -2.21 above.
# In nocorr_onlybin label, m2 is best fit by a power-law -2.26, or -2.06 up to 10.95 Mo and -2.56 above.
# In nocorr_onlybin label, m3 is best fit by a power-law nan, or nan up to 10.95 Mo and nan above.
# In nocorr_onlybin label, m4 is best fit by a power-law nan, or nan up to 10.95 Mo and nan above.
# In nocorr_onlybin label, m5 is best fit by a power-law nan, or nan up to 10.95 Mo and nan above.
# In nocorr_onlybin label, m21 is best fit by a power-law -2.30, or -2.29 up to 10.95 Mo and -2.28 above.
# In nocorr_onlybin label, mall is best fit by a power-law -2.30, or -2.29 up to 10.95 Mo and -2.28 above.
#
# In corr_allmult label, m1 is best fit by a power-law -1.55, or -1.91 up to 10.95 Mo and -0.74 above.
# In corr_allmult label, m2 is best fit by a power-law -1.47, or -1.73 up to 10.95 Mo and -1.54 above.
# In corr_allmult label, m3 is best fit by a power-law -1.33, or -1.34 up to 10.95 Mo and -1.73 above.
# In corr_allmult label, m4 is best fit by a power-law -1.14, or -0.92 up to 10.95 Mo and -1.84 above.
# In corr_allmult label, m5 is best fit by a power-law -0.94, or -0.55 up to 10.95 Mo and -1.90 above.
# In corr_allmult label, m21 is best fit by a power-law -1.51, or -1.86 up to 10.95 Mo and -0.96 above.
# In corr_allmult label, mall is best fit by a power-law -1.44, or -1.74 up to 10.95 Mo and -1.19 above.
#
# In nocorr_allmult label, m1 is best fit by a power-law -2.41, or -2.44 up to 10.95 Mo and -2.29 above.
# In nocorr_allmult label, m2 is best fit by a power-law -2.32, or -2.16 up to 10.95 Mo and -2.52 above.
# In nocorr_allmult label, m3 is best fit by a power-law -2.06, or -1.77 up to 10.95 Mo and -2.36 above.
# In nocorr_allmult label, m4 is best fit by a power-law -1.75, or -1.36 up to 10.95 Mo and -2.13 above.
# In nocorr_allmult label, m5 is best fit by a power-law -1.45, or -1.01 up to 10.95 Mo and -1.87 above.
# In nocorr_allmult label, m21 is best fit by a power-law -2.39, or -2.38 up to 10.95 Mo and -2.34 above.
# In nocorr_allmult label, mall is best fit by a power-law -2.30, or -2.29 up to 10.95 Mo and -2.28 above.

# %%
fig, axes_ = plt.subplots(3, 3, figsize=(24, 14), sharex=True, sharey=True)
axes = axes_.flatten()
fig.subplots_adjust(hspace=0, wspace=0)
rect = fig.patch
rect.set_facecolor('white')



for z, ax in zip(plot_zs, axes):
    sample_paths_ = sample_paths_dict[z]   
    
    for b in np.logspace(-5, 5, 10):
        ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
        #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
        ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
    
    counter = 0
    for path in sample_paths_[:-1]:
        sample_descr = path.name.split('_')[:-3]

        sample_descr_dict = {}
        for attr in sample_descr:
            key, value = attr.split('=')
            sample_descr_dict[key] = value
            
        feh = np.float32(sample_descr_dict['feh'])
        #c = cm.viridis(counter/9)
        c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

        sample_df = pd.read_parquet(path, engine='pyarrow')

        legend = False
        if counter == 0:
            legend = True
            
        plot_imf(ax, sample_df, sample_descr_dict, np.logspace(np.log10(0.08), np.log10(150), 50), legend=False, kroupa=False, mindex=[1], c=c, title=False)
        counter += 1
        
        

 #   for ax in axes[-1, :]:
        #ax.set_xlabel(r'$\log\left(M/\mathrm{M}_\odot\right)$', fontsize=18)
        #ax.set_xticks([1e-1, 1e0, 1e1, 1e2])
        #ax.set_xticklabels(['-1', '0', '1', '2'])
    ax.set_xlim(0.8, 150)
    ax.set_ylim(1e-5, 2e0)

    #for ax in axes[:, 0]:
        #ax.set_ylabel(, fontsize=18)
        #ax.set_yticks([1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8])
        #ax.set_yticklabels(['0', '1', '2', '3', '4', '5', '6', '7', '8'])
        
    z_descr = ax.text(0.95, 0.9, f'$z_\mathrm{{ZAMS}}={z:.2f}$', ha='right', va='top', transform=ax.transAxes, fontsize=30)
    z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
fig.text(0.08, 0.45, r'$\log\left[\xi_g\,\left(m|\mathrm{[Fe/H]},\mathrm{SFR}\right)/(\mathrm{M}_\odot^{-1})\right]$', 
         ha='right', va='center', rotation=90, transform=fig.transFigure)
fig.text(0.5, 0.05, r'$\log\left(m/\mathrm{M}_\odot\right)$', ha='center', va='top')
sm = cm.ScalarMappable(cmap=cm.viridis, norm=plt.Normalize(vmin=min_plot_feh, vmax=max_plot_feh))
cb = fig.colorbar(sm, location='top', aspect=50, ax=axes)
cb.set_label('[Fe/H]')

for ax in axes[[2]]:
    #ax.get_legend().remove()
    handles, labels = ax.get_legend_handles_labels()
    sample_line = Line2D([0], [0], label='$m_2$', color='k', linestyle=':')
    igimf_line = Line2D([0], [0], label='IGIMF', color='k',  linestyle='-')
    kroupa_line = Line2D([0], [0], label='Kroupa', color='k', linestyle='--')
    handles = [sample_line, kroupa_line, igimf_line]
    ax.legend(handles=handles, frameon=False, loc='upper left', bbox_to_anchor=(1,1))
    
    #plt.savefig(FIGURE_FOLDER/f'imfsample_1e2z{100*z:.2f}.pdf', bbox_inches='tight')
    #plt.savefig(FIGURE_FOLDER/f'imfsample_1e2z{100*z:.2f}.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [177], in <cell line: 9>()
#       5 rect.set_facecolor('white')
#       9 for z, ax in zip(plot_zs, axes):
# ---> 10     sample_paths_ = sample_paths_dict[z]
#      12     for b in np.logspace(-5, 5, 10):
#      13         ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
#
# NameError: name 'sample_paths_dict' is not defined

# %%
fig, axes_ = plt.subplots(3, 3, figsize=(24, 14), sharex=True, sharey=True)
axes = axes_.flatten()
fig.subplots_adjust(hspace=0, wspace=0)
rect = fig.patch
rect.set_facecolor('white')



for z, ax in zip(plot_zs, axes):
    sample_paths_ = sample_paths_dict[z]   
    
    for b in np.logspace(-5, 5, 10):
        ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
        #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
        ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
    
    counter = 0
    for path in sample_paths_[:-1]:
        sample_descr = path.name.split('_')[:-3]

        sample_descr_dict = {}
        for attr in sample_descr:
            key, value = attr.split('=')
            sample_descr_dict[key] = value
            
        feh = np.float32(sample_descr_dict['feh'])
        #c = cm.viridis(counter/9)
        c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)

        sample_df = pd.read_parquet(path, engine='pyarrow')

        legend = False
        if counter == 0:
            legend = True
            
        plot_imf(ax, sample_df, sample_descr_dict, np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[-1], c=c, title=False)
        counter += 1
        
        

 #   for ax in axes[-1, :]:
        #ax.set_xlabel(r'$\log\left(M/\mathrm{M}_\odot\right)$', fontsize=18)
        #ax.set_xticks([1e-1, 1e0, 1e1, 1e2])
        #ax.set_xticklabels(['-1', '0', '1', '2'])
    ax.set_xlim(0.8, 150)
    ax.set_ylim(1e-5, 2e0)

    #for ax in axes[:, 0]:
        #ax.set_ylabel(, fontsize=18)
        #ax.set_yticks([1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8])
        #ax.set_yticklabels(['0', '1', '2', '3', '4', '5', '6', '7', '8'])
        
    z_descr = ax.text(0.95, 0.9, f'$z_\mathrm{{ZAMS}}={z:.2f}$', ha='right', va='top', transform=ax.transAxes, fontsize=30)
    z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
fig.text(0.08, 0.45, r'$\log\left[\xi_g\,\left(m|\mathrm{[Fe/H]},\mathrm{SFR}\right)/(\mathrm{M}_\odot^{-1})\right]$', 
         ha='right', va='center', rotation=90, transform=fig.transFigure)
fig.text(0.5, 0.05, r'$\log\left(m/\mathrm{M}_\odot\right)$', ha='center', va='top')
sm = cm.ScalarMappable(cmap=cm.viridis, norm=plt.Normalize(vmin=min_plot_feh, vmax=max_plot_feh))
cb = fig.colorbar(sm, location='top', aspect=50, ax=axes)
cb.set_label('[Fe/H]')

for ax in axes[[2]]:
    #ax.get_legend().remove()
    handles, labels = ax.get_legend_handles_labels()
    sample_line = Line2D([0], [0], label='All $m_i$', color='k', linestyle=':')
    igimf_line = Line2D([0], [0], label='IGIMF', color='k',  linestyle='-')
    kroupa_line = Line2D([0], [0], label='Kroupa', color='k', linestyle='--')
    handles = [sample_line, kroupa_line, igimf_line]
    ax.legend(handles=handles, frameon=False, loc='upper left', bbox_to_anchor=(1,1))
    
    #plt.savefig(FIGURE_FOLDER/f'imfsample_1e2z{100*z:.2f}.pdf', bbox_inches='tight')
    #plt.savefig(FIGURE_FOLDER/f'imfsample_1e2z{100*z:.2f}.png', bbox_inches='tight')

# %% [raw]
# gridspec = dict(hspace=0.0, wspace=0.0, height_ratios=[1, 1, 1,
#                                           0.3,
#                                           1, 1, 1,
#                                           0.3,
#                                           1, 1, 1])
#
# fig, axes_ = plt.subplots(11, 3, figsize=(21.0, 29.7), sharex=True, sharey=True, gridspec_kw=gridspec)
# axes0 = axes_[[0,1,2]].flatten()
# axes1 = axes_[[4,5,6]].flatten()
# axes2 = axes_[[8,9,10]].flatten()
# #fig.subplots_adjust(hspace=0, wspace=0)
# rect = fig.patch
# rect.set_facecolor('white')
#
# for ax in axes_[3]:
#     ax.set_visible(False)
# for ax in axes_[7]:
#     ax.set_visible(False)
#
# for z, ax in zip(plot_zs, axes0):
#     sample_paths_ = sample_paths_dict[z]
#
#     for b in np.logspace(-5, 5, 10):
#         ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
#         #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
#         ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
#
#     counter = 0
#     for path in sample_paths_:#[-1:]:
#         sample_descr = path.name.split('_')[:-3]
#
#         sample_descr_dict = {}
#         for attr in sample_descr:
#             key, value = attr.split('=')
#             sample_descr_dict[key] = value
#
#         feh = np.float32(sample_descr_dict['feh'])
#         #c = cm.viridis(counter/9)
#         c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)
#
#         sample_df = pd.read_parquet(path, engine='pyarrow')
#
#         legend = False
#         if counter == 0:
#             legend = True
#
#         plot_imf(ax, sample_df, sample_descr_dict, np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[-1], c=c, title=False)
#         counter += 1
#
#     ax.set_xlim(0.8, 150)
#     ax.set_ylim(1e-5, 2e0)
#
#     z_descr = ax.text(0.95, 0.9, f'$z_\mathrm{{ZAMS}}={z:.2f}$', ha='right', va='top', transform=ax.transAxes, fontsize=30)
#     z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
#
#
# for z, ax in zip(plot_zs, axes1):
#     sample_paths_ = sample_paths_dict[z]
#
#     for b in np.logspace(-5, 5, 10):
#         ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
#         #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
#         ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
#
#     counter = 0
#     for path in sample_paths_:#[-1:]:
#         sample_descr = path.name.split('_')[:-3]
#
#         sample_descr_dict = {}
#         for attr in sample_descr:
#             key, value = attr.split('=')
#             sample_descr_dict[key] = value
#
#         feh = np.float32(sample_descr_dict['feh'])
#         #c = cm.viridis(counter/9)
#         c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)
#
#         sample_df = pd.read_parquet(path, engine='pyarrow')
#
#         legend = False
#         if counter == 0:
#             legend = True
#
#         plot_imf(ax, sample_df, sample_descr_dict, np.logspace(np.log10(0.08), np.log10(150), 50), legend=False, kroupa=False, mindex=[1], c=c, title=False)
#         counter += 1
#
#     ax.set_xlim(0.8, 150)
#     ax.set_ylim(1e-5, 2e0)
#
#     z_descr = ax.text(0.95, 0.9, f'$z_\mathrm{{ZAMS}}={z:.2f}$', ha='right', va='top', transform=ax.transAxes, fontsize=30)
#     z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
#
# for z, ax in zip(plot_zs, axes2):
#     sample_paths_ = sample_paths_dict[z]
#
#     for b in np.logspace(-5, 5, 10):
#         ms = np.concatenate((np.logspace(-2, np.log10(0.5), 20), np.logspace(np.log10(0.5), 2.5, 21)[1:]))
#         #ax.plot(ms, 0.5*b*ms**-2.3, 'k--', lw=1, alpha=0.5)
#         ax.plot(ms, [0.5*b*kroupa_imf(m) for m in ms], 'k--', lw=1, alpha=0.5)
#
#     counter = 0
#     for path in sample_paths_:#[-1:]:
#         sample_descr = path.name.split('_')[:-3]
#
#         sample_descr_dict = {}
#         for attr in sample_descr:
#             key, value = attr.split('=')
#             sample_descr_dict[key] = value
#
#         feh = np.float32(sample_descr_dict['feh'])
#         #c = cm.viridis(counter/9)
#         c = cm.viridis((feh-min_plot_feh)/norm_plot_feh)
#
#         sample_df = pd.read_parquet(path, engine='pyarrow')
#
#         legend = False
#         if counter == 0:
#             legend = True
#
#         plot_imf(ax, sample_df, sample_descr_dict, np.logspace(np.log10(0.8), np.log10(150), 50), legend=False, kroupa=False, mindex=[-1], c=c, title=False)
#         counter += 1
#
#     ax.set_xlim(0.8, 150)
#     ax.set_ylim(1e-5, 2e0)
#     z_descr = ax.text(0.95, 0.9, f'$z_\mathrm{{ZAMS}}={z:.2f}$', ha='right', va='top', transform=ax.transAxes, fontsize=30)
#     z_descr.set_bbox(dict(facecolor='white', alpha=0.6, edgecolor='gray'))
#
# axes_[1, 0].set_ylabel(r'$\log\left[\xi_g\,\left(m|\mathrm{[Fe/H]},\mathrm{SFR}\right)/(\mathrm{M}_\odot^{-1})\right]$', fontsize=36)
# #axes_[2, 1].set_xlabel(r'$\log\left(m/\mathrm{M}_\odot\right)$')
# axes_[5, 0].set_ylabel(r'$\log\left[\xi_g\,\left(m|\mathrm{[Fe/H]},\mathrm{SFR}\right)/(\mathrm{M}_\odot^{-1})\right]$', fontsize=36)
# #axes_[6, 1].set_xlabel(r'$\log\left(m/\mathrm{M}_\odot\right)$')
# axes_[9, 0].set_ylabel(r'$\log\left[\xi_g\,\left(m|\mathrm{[Fe/H]},\mathrm{SFR}\right)/(\mathrm{M}_\odot^{-1})\right]$', fontsize=36)
# axes_[10, 1].set_xlabel(r'$\log\left(m/\mathrm{M}_\odot\right)$', fontsize=36)
#
# sm = cm.ScalarMappable(cmap=cm.viridis, norm=plt.Normalize(vmin=min_plot_feh, vmax=max_plot_feh))
# cb = fig.colorbar(sm, location='top', aspect=50, ax=axes)
# cb.set_label('[Fe/H]')
#
# axes0[1].set_title('$m_1$ distribution', fontsize=36)
# axes1[1].set_title('$m_2$ distribution', fontsize=36)
# axes2[1].set_title('All $m_i$ distribution', fontsize=36)
#
# for ax in [axes0[2]]:
#     sample_line = Line2D([0], [0], label='Sample', color='k', linestyle=':')
#     igimf_line = Line2D([0], [0], label='IGIMF', color='k',  linestyle='-')
#     kroupa_line = Line2D([0], [0], label='Kroupa', color='k', linestyle='--')
#     handles = [sample_line, kroupa_line, igimf_line]
#     ax.legend(handles=handles, frameon=False, loc='upper left', bbox_to_anchor=(1,1), fontsize=36)
#
# plt.savefig(FIGURE_FOLDER/f'imfsampling_1222_1e4.pdf', bbox_inches='tight')
# plt.savefig(FIGURE_FOLDER/f'imfsampling_1222_1e4.png', bbox_inches='tight')
