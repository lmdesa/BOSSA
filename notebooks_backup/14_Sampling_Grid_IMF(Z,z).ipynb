# %% [markdown]
# # Notebook 34: Optimal sampling of the IGIMF from a grid of galaxies sampled from the GSMF

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pathlib import Path
import pandas as pd
try:
    import cPickle as pickle
except ModuleNotFoundError:
    import pickle
    
import time
    
import sys
sys.path.append('../src/')
from sfr_old import SFZR
from imf import IGIMF
from sampling import OSGIMF, RandomSampling, save_osgimf_instance
from utils import sample_histogram, ZOH_from_FeH, FeH_to_Z, ZOH_to_FeH
from zdf import NeijsselZDF, MetallicityPicker
import constants as ct

# %%
DATA_FOLDER = Path('..', 'Data')
OSGIMF_FOLDER = Path(DATA_FOLDER, 'OSGIMFs')
GALAXYGRID_PATH = Path(DATA_FOLDER, 'Galaxy_Grid', 'z0-10-1_5bin_galaxygrid.pkl')

# %%
galaxygrid_df = pd.read_pickle(GALAXYGRID_PATH)

# %%
galaxygrid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Redshift                            54 non-null     float64
#  1   Log(Mgal/Msun)                      54 non-null     float64
#  2   Log(Number density [Mpc-3 Msun-1])  54 non-null     float64
#  3   SFR [Msun yr-1]                     54 non-null     float64
#  4   12+log(O/H)                         54 non-null     float64
#  5   [Fe/H]                              54 non-null     float64
# dtypes: float64(6)
# memory usage: 2.7 KB

# %%
galaxygrid_df
# Out:
#     Redshift  Log(Mgal/Msun)  Log(Number density [Mpc-3 Msun-1])  \
# 0       0.01       11.003143                           -3.239432
# 1       0.01       10.663365                           -2.744230
# 2       0.01       10.350333                           -2.475242
# 3       0.01        9.934082                           -2.241326
# 4       0.01        7.870006                           -1.501990
# 5       1.01       11.004360                           -3.402835
# 6       1.01       10.667811                           -2.909475
# 7       1.01       10.358573                           -2.643631
# 8       1.01        9.947751                           -2.415168
# 9       1.01        7.848946                           -1.645590
# 10      2.01       11.098165                           -3.728585
# 11      2.01       10.757498                           -3.233370
# 12      2.01       10.442810                           -2.964041
# 13      2.01       10.021883                           -2.728858
# 14      2.01        7.828643                           -1.856704
# 15      3.01       11.123955                           -4.249048
# 16      3.01       10.676986                           -3.687060
# 17      3.01       10.234328                           -3.303937
# 18      3.01        9.642355                           -2.880588
# 19      3.01        7.737171                           -1.887167
# 20      4.01       10.987584                           -4.560265
# 21      4.01       10.424910                           -3.876512
# 22      4.01        9.915220                           -3.357773
# 23      4.01        9.384247                           -2.856727
# 24      4.01        7.704408                           -2.100800
# 25      5.01       10.893320                           -4.845004
# 26      5.01       10.355964                           -4.127922
# 27      5.01        9.936978                           -3.629092
# 28      5.01        9.487702                           -3.330121
# 29      5.01        7.722827                           -2.535927
# 30      6.01       10.760319                           -4.896345
# 31      6.01       10.229794                           -4.150165
# 32      6.01        9.845226                           -3.650541
# 33      6.01        9.407506                           -3.416180
# 34      6.01        7.709012                           -2.651858
# 35      7.01       10.393257                           -4.701397
# 36      7.01       10.007855                           -4.102105
# 37      7.01        9.703987                           -3.791456
# 38      7.01        9.275759                           -3.598754
# 39      7.01        7.684905                           -2.882870
# 40      8.01       10.318323                           -5.762933
# 41      8.01        9.939676                           -5.132271
# 42      8.01        9.648595                           -4.858406
# 43      8.01        9.222146                           -4.666504
# 44      8.01        7.674578                           -3.970098
# 45      9.01       10.274738                           -5.769317
# 46      9.01        9.904975                           -5.124515
# 47      9.01        9.620110                           -4.877251
# 48      9.01        9.194519                           -4.685734
# 49      9.01        7.669137                           -3.999313
# 50     10.01       10.205065                           -5.707641
# 51     10.01        9.860067                           -5.068811
# 52     10.01        9.582477                           -4.868884
# 53     10.01        9.158076                           -4.677903
#
#     SFR [Msun yr-1]  12+log(O/H)    [Fe/H]
# 0          0.851880     9.207693  0.755386
# 1          0.631902     9.190830  0.721660
# 2          0.432884     9.168100  0.676200
# 3          0.173025     9.122819  0.585637
# 4         -1.045828     8.523687 -0.612627
# 5          1.532782     9.176521  0.693041
# 6          1.303728     9.140436  0.620872
# 7          1.097949     9.096570  0.533139
# 8          0.831028     9.019471  0.378943
# 9         -0.450232     8.317142 -1.012858
# 10         1.971992     9.100363  0.540725
# 11         1.729819     9.047627  0.435254
# 12         1.512003     8.984482  0.308964
# 13         1.229640     8.876233  0.092466
# 14        -0.141292     7.994941 -1.335059
# 15         2.101192     8.937520  0.215040
# 16         1.781022     8.854508  0.049017
# 17         1.476108     8.739005 -0.181991
# 18         1.087917     8.531486 -0.597028
# 19        -0.084478     7.637057 -1.692943
# 20         2.084972     8.694062 -0.271876
# 21         1.687237     8.574564 -0.510873
# 22         1.345622     8.418219 -0.823562
# 23         1.000612     8.211810 -1.118190
# 24        -0.019808     7.403510 -1.926490
# 25         2.082890     8.477694 -0.704611
# 26         1.706370     8.356135 -0.947731
# 27         1.426591     8.225826 -1.104174
# 28         1.137232     8.053645 -1.276355
# 29         0.060166     7.213113 -2.116887
# 30         2.044221     8.252201 -1.077799
# 31         1.677249     8.120190 -1.209810
# 32         1.423134     7.993209 -1.336791
# 33         1.139308     7.821338 -1.508662
# 34         0.114570     7.005911 -2.324089
# 35         1.837867     7.966209 -1.363791
# 36         1.579439     7.850045 -1.479955
# 37         1.382741     7.740310 -1.589690
# 38         1.102366     7.566469 -1.763531
# 39         0.158158     6.793334 -2.536666
# 40         1.832171     7.745712 -1.584288
# 41         1.580672     7.626763 -1.703237
# 42         1.394331     7.518710 -1.811290
# 43         1.115253     7.343542 -1.986458
# 44         0.205740     6.587942 -2.742058
# 45         1.845460     7.533323 -1.796677
# 46         1.601566     7.414609 -1.915391
# 47         1.420798     7.307422 -2.022578
# 48         1.143392     7.131599 -2.198401
# 49         0.253677     6.385100 -2.944900
# 50         1.840240     7.312808 -2.017192
# 51         1.614955     7.198580 -2.131420
# 52         1.440615     7.092324 -2.237676
# 53         1.165020     6.915716 -2.414284

# %% [markdown]
# #### Generating one star sample

# %% [raw]
# test1_z = 1.01
# test1_feh = -1.01
# test1_sfr = 10**-0.53
# test1_deltat = 1e7
# test1_m_min = 5

# %% [raw]
# test1_osgimf = OSGIMF(test1_z, test1_feh, test1_sfr, test1_m_min, delta_t=test1_deltat)

# %% [raw]
# test2_osgimf = OSGIMF(test1_z, test1_feh, test1_sfr, test1_m_min, delta_t=test1_deltat, precalculate_limits=True)

# %% [raw]
# %%time
# test1_osgimf.sample_clusters()

# %% [raw]
# %%time
# test2_osgimf.sample_clusters()

# %% [raw]
# %%time
# test1_osgimf.sample_stars()

# %% [raw]
# %%time
# test2_osgimf.sample_stars()

# %% [raw]
# test1_osgimf.star_sample.shape[0]/1e6

# %% [raw]
# test2_osgimf.star_sample.shape[0]/1e6

# %% [raw]
# test1_igimf = IGIMF(test1_sfr, test1_feh)
# test1_igimf.get_clusters()
# test1_randomsampler = RandomSampling(test1_igimf)

# %% [raw]
# test2_igimf = IGIMF(test1_sfr, test1_feh)
# test2_igimf.get_clusters()
# test2_randomsampler = RandomSampling(test2_igimf)

# %% [raw]
# test1_randomsampler.compute_imf()

# %% [raw]
# test2_randomsampler.compute_imf()

# %% [raw]
# test1_randomsample = test1_randomsampler.get_sample(5, 150, 1e5)
# test1_igimf_masses = test1_randomsampler._discretization_masses
# test1_igimf = test1_randomsampler.discrete_imf

# %% [raw]
# test2_randomsample = test2_randomsampler.get_sample(5, 150, 1e5)
# test2_igimf_masses = test2_randomsampler._discretization_masses
# test2_igimf = test2_randomsampler.discrete_imf

# %% [raw]
# fig, ax = plt.subplots(figsize=(8,6))
#
# osgimf_hist = sample_histogram(test1_osgimf.star_sample, 50, 0.08)
# random_hist = sample_histogram(test1_randomsample, 50, 0.08)
#
# ax.plot(random_hist[:,0], random_hist[:,1], 'c-')
# ax.plot(osgimf_hist[:,0], osgimf_hist[:,1], 'r-', lw=0.5, label='Sampled IMF')
# ax.plot(test1_igimf_masses, test1_igimf, color='orange')
#
#
# ax.set_xlabel(r'$M_\ast\,[M_\odot]$', fontsize=22)
# ax.set_ylabel(r'$dN/dM\,[M_\odot^{-1}]$', fontsize=22)
# #ax.set_title(f'Optimally sampled IGIMF (SFR = {osgimf.sfr:.2e} $M_\odot$yr$^{{-1}}$, [Fe/H]={osgimf.feh:.2f})', fontsize=20)
# ax.legend(loc=(0.55, 0.9), fontsize=16, frameon=False)
#
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.tick_params(axis='both', direction='in', labelsize=16)
#
# sci_sfr = f'{test1_osgimf.sfr:.2e}'.split('e')
# param_string = f'$z = {test1_osgimf.z:.2f}$\n$Z = 10^{{{test1_osgimf.feh:.2f}}}\,Z_\odot$\n$\mathrm{{SFR}} = {sci_sfr[0]}\mathrm{{x}}10^{{{sci_sfr[1][-1]}}}\,M_\odot\,\mathrm{{yr}}^{{-1}}$'
#
# ax.text(0.55, 0.7, param_string, transform=ax.transAxes, fontsize=16)
# ax.text(0.2, 0.1, f'{test1_osgimf.star_sample.shape[0]} stars, \n 50 in each mass bin', fontsize=20, transform=ax.transAxes)

# %% [raw]
# fig, ax = plt.subplots(figsize=(8,6))
#
# osgimf_hist = sample_histogram(test2_osgimf.star_sample, 50, 0.08)
# random_hist = sample_histogram(test2_randomsample, 50, 0.08)
#
# ax.plot(random_hist[:,0], random_hist[:,1], 'c-')
# ax.plot(osgimf_hist[:,0], osgimf_hist[:,1], 'r-', lw=0.5, label='Sampled IMF')
# ax.plot(test2_igimf_masses, test2_igimf, color='orange')
#
#
# ax.set_xlabel(r'$M_\ast\,[M_\odot]$', fontsize=22)
# ax.set_ylabel(r'$dN/dM\,[M_\odot^{-1}]$', fontsize=22)
# #ax.set_title(f'Optimally sampled IGIMF (SFR = {osgimf.sfr:.2e} $M_\odot$yr$^{{-1}}$, [Fe/H]={osgimf.feh:.2f})', fontsize=20)
# ax.legend(loc=(0.55, 0.9), fontsize=16, frameon=False)
#
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.tick_params(axis='both', direction='in', labelsize=16)
#
# sci_sfr = f'{test2_osgimf.sfr:.2e}'.split('e')
# param_string = f'$z = {test2_osgimf.z:.2f}$\n$Z = 10^{{{test2_osgimf.feh:.2f}}}\,Z_\odot$\n$\mathrm{{SFR}} = {sci_sfr[0]}\mathrm{{x}}10^{{{sci_sfr[1][-1]}}}\,M_\odot\,\mathrm{{yr}}^{{-1}}$'
#
# ax.text(0.55, 0.7, param_string, transform=ax.transAxes, fontsize=16)
# ax.text(0.2, 0.1, f'{test2_osgimf.star_sample.shape[0]} stars, \n 50 in each mass bin', fontsize=20, transform=ax.transAxes)

# %% [raw]
# test1_filename = f'osgimf_100z{test1_osgimf.z*100:.0f}_100FeH{100*test1_osgimf.feh:.0f}_100logsfr{100*np.log10(test1_osgimf.sfr):.0f}.pkl'
# test1_filepath = Path(OSGIMF_FOLDER, test1_filename)

# %% [raw]
# print(f'Saving file {test1_filename}')
# save_osgimf_instance(test1_osgimf, test1_filepath)

# %% [markdown]
# #### Generating a grid of samples

# %%
def get_sample(z, feh, sfr, filepath=None):
    if filepath.is_file():
        print(f'File {filepath} already exists. Skipping...')
        return
    osgimf = OSGIMF(z, feh, sfr, 5, delta_t=1e7, precalculate_limits=False)
    print('Sampling clusters')
    time1 = time.time()
    osgimf.sample_clusters()
    time2 = time.time()
    print(f'Cluster sampling complete. Elapsed time: {time2-time1} s')
    print('Sampling stars')
    time1 = time.time()
    osgimf.sample_stars()
    time2 = time.time()
    print(f'Star sampling complete. Elapsed time: {time2-time1} s')
    print('Saving')
    save_osgimf_instance(osgimf, filepath)

# %%
for row in galaxygrid_df.to_numpy():
    z, logmass, density, logsfr, zoh, feh = row
    filename = f'osgimf_100z{z*100:.0f}_100FeH{100*feh:.0f}_100losfr{100*logsfr:.0f}.pkl'
    filepath = Path(OSGIMF_FOLDER, filename)
    print(f'Now sampling at z = {z}, logSFR = {logsfr}, [Fe/H] = {feh} s')
    start_time = time.time()
    get_sample(z, feh, 10**logsfr, filepath)
    end_time = time.time()
    print(f'Sample saved. Elapsed time: {end_time-start_time} s')
    print(' ')
# Out:
# Now sampling at z = 0.01, logSFR = 0.8518795437284586, [Fe/H] = 0.7553864897636564 s
# File ..\Data\OSGIMFs\osgimf_100z1_100FeH76_100losfr85.pkl already exists. Skipping...
# Sample saved. Elapsed time: 0.0 s
#
# Now sampling at z = 0.01, logSFR = 0.6319016263482723, [Fe/H] = 0.7216602221225621 s
# File ..\Data\OSGIMFs\osgimf_100z1_100FeH72_100losfr63.pkl already exists. Skipping...
# Sample saved. Elapsed time: 0.0010001659393310547 s
#
# Now sampling at z = 0.01, logSFR = 0.43288356559772817, [Fe/H] = 0.6761998813493197 s
# File ..\Data\OSGIMFs\osgimf_100z1_100FeH68_100losfr43.pkl already exists. Skipping...
# Sample saved. Elapsed time: 0.0 s
#
# Now sampling at z = 0.01, logSFR = 0.17302459358096683, [Fe/H] = 0.5856372941605059 s
# File ..\Data\OSGIMFs\osgimf_100z1_100FeH59_100losfr17.pkl already exists. Skipping...
# Sample saved. Elapsed time: 0.0010154247283935547 s
#
# Now sampling at z = 0.01, logSFR = -1.0458277426556235, [Fe/H] = -0.612626593664023 s
# File ..\Data\OSGIMFs\osgimf_100z1_100FeH-61_100losfr-105.pkl already exists. Skipping...
# Sample saved. Elapsed time: 0.0009999275207519531 s
#
# Now sampling at z = 1.01, logSFR = 1.5327820248809312, [Fe/H] = 0.6930411276001105 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 4253.497755050659 s
# Sampling stars
# Star sampling complete. Elapsed time: 16718.13662648201 s
# Saving
# Sample saved. Elapsed time: 20971.774953365326 s
#
# Now sampling at z = 1.01, logSFR = 1.3037279857983433, [Fe/H] = 0.6208716776577505 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 2838.194455385208 s
# Sampling stars
# Star sampling complete. Elapsed time: 8675.228254079819 s
# Saving
# Sample saved. Elapsed time: 11513.500837802887 s
#
# Now sampling at z = 1.01, logSFR = 1.0979493911719018, [Fe/H] = 0.5331390463934209 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 1940.5965089797974 s
# Sampling stars
# Star sampling complete. Elapsed time: 4622.631575345993 s
# Saving
# Sample saved. Elapsed time: 6563.259335041046 s
#
# Now sampling at z = 1.01, logSFR = 0.8310280948057635, [Fe/H] = 0.3789428138209989 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 1113.7149155139923 s
# Sampling stars
# Star sampling complete. Elapsed time: 2066.4713850021362 s
# Saving
# Sample saved. Elapsed time: 3180.2019317150116 s
#
# Now sampling at z = 1.01, logSFR = -0.4502320135831983, [Fe/H] = -1.0128580000623706 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 6.447751045227051 s
# Sampling stars
# Star sampling complete. Elapsed time: 27.565383911132812 s
# Saving
# Sample saved. Elapsed time: 34.02876019477844 s
#
# Now sampling at z = 2.01, logSFR = 1.9719919424079548, [Fe/H] = 0.5407252351403637 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 7856.588628053665 s
# Sampling stars
# Star sampling complete. Elapsed time: 64585.664363622665 s
# Saving
# Sample saved. Elapsed time: 72444.66607785225 s
#
# Now sampling at z = 2.01, logSFR = 1.7298190156042812, [Fe/H] = 0.4352544261855811 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 5708.559151887894 s
# Sampling stars
# Star sampling complete. Elapsed time: 32346.820254325867 s
# Saving
# Sample saved. Elapsed time: 38055.86685204506 s
#
# Now sampling at z = 2.01, logSFR = 1.5120030603094943, [Fe/H] = 0.30896361791912685 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 4368.464697360992 s
# Sampling stars
# Star sampling complete. Elapsed time: 17087.709662675858 s
# Saving
# Sample saved. Elapsed time: 21456.39311170578 s
#
# Now sampling at z = 2.01, logSFR = 1.229639960306685, [Fe/H] = 0.09246618673933105 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 2567.434953927994 s
# Sampling stars
# Star sampling complete. Elapsed time: 7141.635802984238 s
# Saving
# Sample saved. Elapsed time: 9709.1020591259 s
#
# Now sampling at z = 2.01, logSFR = -0.14129182030549473, [Fe/H] = -1.3350594050788709 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 24.56387996673584 s
# Sampling stars
# Star sampling complete. Elapsed time: 59.77569031715393 s
# Saving
# Sample saved. Elapsed time: 84.37081027030945 s
#
# Now sampling at z = 3.01, logSFR = 2.10119234486988, [Fe/H] = 0.21504029817472725 s
# Sampling clusters
# cluster imf set
# sampler created
# Cluster sampling complete. Elapsed time: 8950.067809581757 s
# Sampling stars

# %%
osgimf_files = list(OSGIMF_FOLDER.glob('*.pkl'))

# %%
osgimfs = []

for file in osgimf_files:
    with file.open('rb') as f:
        osgimf = pickle.load(f)
    osgimfs.append(osgimf)

# %%
starcount_array = np.empty(0, np.float64)
metallicity_array = np.empty(0, np.float64)

for osgimf in osgimfs:
    fig, ax = plt.subplots(figsize=(8,6))

    osgimf_hist = sample_histogram(osgimf.star_sample, 50)

    ax.plot(osgimf_hist[:,0],osgimf_hist[:,1], 'b-', lw=0.5, label='Sampled IMF')

    ax.set_xlabel(r'$M_\ast\,[M_\odot]$', fontsize=22)
    ax.set_ylabel(r'$dN/dM\,[M_\odot^{-1}]$', fontsize=22)
    #ax.set_title(f'Optimally sampled IGIMF (SFR = {osgimf.sfr:.2e} $M_\odot$yr$^{{-1}}$, [Fe/H]={osgimf.feh:.2f})', fontsize=20)
    ax.legend(loc=(0.55, 0.9), fontsize=16, frameon=False)

    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.tick_params(axis='both', direction='in', labelsize=16)

    sci_sfr = f'{osgimf.sfr:.2e}'.split('e')
    param_string = f'$z = {osgimf.z:.2f}$\n$Z = 10^{{{osgimf.feh:.2f}}}\,Z_\odot$\n$\mathrm{{SFR}} = {sci_sfr[0]}\mathrm{{x}}10^{{{sci_sfr[1][-1]}}}\,M_\odot\,\mathrm{{yr}}^{{-1}}$'
    
    ax.text(0.55, 0.7, param_string, transform=ax.transAxes, fontsize=16)
    ax.text(0.2, 0.1, f'{osgimf.star_sample.shape[0]} stars, \n 50 in each mass bin', fontsize=20, transform=ax.transAxes)
    
    starcount_array = np.append(star_count_array, osgimf.star_sample.shape[0])
    metallicity_array = np.append(metallicity_array, osgimf.feh)
    
sorted_indexes = np.argsort(metallicity_array)
metallicity_array = metallicity_array[sorted_indexes]
starcount_array = star_count_array[sorted_indexes]

# %%
starcount_array = np.empty(0, np.float64)
metallicity_array = np.empty(0, np.float64)

for osgimf in osgimfs:
    fig, ax = plt.subplots(figsize=(8,6))

    osgimf_hist = sample_histogram(osgimf.star_sample, 50)

    ax.plot(osgimf_hist[:,0],osgimf_hist[:,1], 'b-', lw=0.5, label='Sampled IMF')

    ax.set_xlabel(r'$M_\ast\,[M_\odot]$', fontsize=22)
    ax.set_ylabel(r'$dN/dM\,[M_\odot^{-1}]$', fontsize=22)
    #ax.set_title(f'Optimally sampled IGIMF (SFR = {osgimf.sfr:.2e} $M_\odot$yr$^{{-1}}$, [Fe/H]={osgimf.feh:.2f})', fontsize=20)
    ax.legend(loc=(0.55, 0.9), fontsize=16, frameon=False)

    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.tick_params(axis='both', direction='in', labelsize=16)

    sci_sfr = f'{osgimf.sfr:.2e}'.split('e')
    param_string = f'$z = {osgimf.z:.2f}$\n$Z = 10^{{{osgimf.feh:.2f}}}\,Z_\odot$\n$\mathrm{{SFR}} = {sci_sfr[0]}\mathrm{{x}}10^{{{sci_sfr[1][-1]}}}\,M_\odot\,\mathrm{{yr}}^{{-1}}$'
    
    ax.text(0.55, 0.7, param_string, transform=ax.transAxes, fontsize=16)
    ax.text(0.2, 0.1, f'{osgimf.star_sample.shape[0]} stars, \n 50 in each mass bin', fontsize=20, transform=ax.transAxes)
    
    starcount_array = np.append(star_count_array, osgimf.star_sample.shape[0])
    metallicity_array = np.append(metallicity_array, osgimf.feh)
    
sorted_indexes = np.argsort(metallicity_array)
metallicity_array = metallicity_array[sorted_indexes]
starcount_array = star_count_array[sorted_indexes]
